# %%
# imports
import statistics
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline

# %% [markdown]
# # Breaking down intuitively the concept of standard deviation
#
# What people usually think, when asked to explain what is standard deviation, is how much a measurement moves, on average, everyday. Which is wrong. The central idea of STD is how much a measurement differs from the mean of its distributtion.
#
# In Sicily, Italy, the temperature, on average, is 85°F. The standard deviation, as Fat Tony would explain is how much, far from 85°F, the current temperature is.
# Today is slighly colder than usual, it's 5°F colder than usual.
#
# ### Being a Nerd
#
# The standard deviation is a statistic that measures the dispersion of a dataset relative to its mean.
#
# <div style="text-align: center">
#  <img width="350" src="https://latex.codecogs.com/svg.image?\sigma&space;=&space;\sqrt{\frac{1}{n}&space;\sum&space;(x_{i}&space;-&space;\mu&space;&space;)^2}">
# </div>
#
# As you can easily see, what is being calculated is the distance between two one dimensional coordinates. The distributtion mean and the current value of a random variable.

# %%
averageSicilyHighTemperature = [15,15,16,18,22,25,28,30,27,23,19,16,20]
averageSicilyLowTemperature = [10,10,11,13,16,20,23,24,22,18,14,11,16]

print(statistics.stdev(averageSicilyHighTemperature))
print(statistics.stdev(averageSicilyLowTemperature))
# Out:
# 5.1875096539916346
# 5.033222956847166

# %% [markdown]
# The above values show how much each array value differs from the distribuittion's mean. Not how much the value moves in average, everyday.
#
#
# ## The Gaussian

# %%
# define constants
mu = 998.8 
sigma = 73.10
x1 = 900
x2 = 1100

# calculate the z-transform
z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma

x = np.arange(z1, z2, 0.001) # range of x in spec
x_all = np.arange(-10, 10, 0.001) # entire range of x, both in and out of spec
# mean = 0, stddev = 1, since Z-transform was calculated
y = norm.pdf(x,0,1)
y2 = norm.pdf(x_all,0,1)

# build the plot
fig, ax = plt.subplots(figsize=(9,6))
plt.style.use('fivethirtyeight')
ax.plot(x_all,y2)

ax.fill_between(x,y,0, alpha=0.3, color='b')
ax.fill_between(x_all,y2,0, alpha=0.1)
ax.set_xlim([-4,4])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_yticklabels([])
ax.set_title('Normal Gaussian Curve')

plt.savefig('normal_curve.png', dpi=72, bbox_inches='tight')
plt.show()

# %% [markdown]
# One of the most important applications of standard deviation is when applied to gaussian distributtions. The most majority possibility of an event happen is in a span of a standard deviation, when a gaussian is considered the distributtion.
#
# One consequence of fat tails is the probability of happening an event outside of the first std span, but when it happens, we have what is called a black swan.
