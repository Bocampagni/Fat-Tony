# %%
import pandas as pd
tabela_dieta_csv = pd.read_csv('dietaDados.csv')
tabela_dieta_csv.T
# Out:
#                                                   0                 1   \
# Mercadoria            Farinha de trigo (enriquecida)  Farinha de milho
# Calorias(1000)                                  44.0              36.0
# Proteinas(gramas)                                  7               897
# Cálcio(gramas)                                  1411               1.7
# Ferro(mg)                                        2.0                99
# Vitamina A(1000I.U.)                             365              30.9
# Tiamina(mg.)                                       -              17.4
# Riboflavina(mg.)                                55.4               7.9
# Niacina(mg.)                                    33.3               106
# Ácido Ascórbico(mg.)                             441                 -
#
#                                           2          3                 4   \
# Mercadoria            Leite evaporado (lata)  Margarina  Queijo (cheddar)
# ...
